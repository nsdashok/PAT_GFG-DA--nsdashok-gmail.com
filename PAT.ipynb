# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data=pd.read_csv("data.csv")

# %%
# To View first five.
data.head()
# Out:
#                      product_name      brand_name  rating  rating_count  \
# 0   Croc Textured Two Fold Wallet     Lino Perros     0.0             0
# 1             Men Striped Sliders  Mast & Harbour     4.0            76
# 2            Printed A-line Kurta            Biba     4.3            66
# 3    Girls Floral Printed T-shirt        Anthrilo     0.0             0
# 4  Women Printed Kurta with Skirt    FASHION DWAR     0.0             0
#
#    marked_price  discounted_price                      sizes  \
# 0          1295               828                    Onesize
# 1          1299               584  UK6,UK7,UK8,UK9,UK10,UK11
# 2          1999              1599           S,M,L,XL,XXL,3XL
# 3           599               539            7-8Y,8-9Y,9-10Y
# 4          2899              2899                   S,M,L,XL
#
#                                         product_link  \
# 0  wallets/lino-perros/lino-perros-women-peach-co...
# 1  flip-flops/mast--harbour/mast--harbour-men-nav...
# 2  kurtas/biba/biba-women-off-white--black-printe...
# 3  tshirts/anthrilo/anthrilo-girls-white-floral-p...
# 4  kurta-sets/fashion-dwar/fashion-dwar-women-mul...
#
#                                             img_link product_tag  \
# 0  https://assets.myntassets.com/dpr_2,q_60,w_210...     wallets
# 1  https://assets.myntassets.com/dpr_2,q_60,w_210...  flip-flops
# 2  https://assets.myntassets.com/dpr_2,q_60,w_210...      kurtas
# 3  https://assets.myntassets.com/dpr_2,q_60,w_210...     tshirts
# 4  https://assets.myntassets.com/dpr_2,q_60,w_210...  kurta-sets
#
#        brand_tag  discount_amount  discount_percent
# 0    lino-perros              467                36
# 1  mast--harbour              715                55
# 2           biba              400                20
# 3       anthrilo               60                10
# 4   fashion-dwar                0                 0

# %%
# To View last five.
data.tail()
# Out:
#                               product_name brand_name  rating  rating_count  \
# 168024          Ethnic Motifs Kaftan Dress       Soch     0.0             0
# 168025  Leather Wedge Sandals with Tassels    fitflop     0.0             0
# 168026                 Leather Wedge Pumps    fitflop     0.0             0
# 168027      V015 Professional Hair Trimmer        VGR     0.0             0
# 168028                Women Open Toe Flats     daisie     0.0             0
#
#         marked_price  discounted_price  \
# 168024          3998              3998
# 168025          6799              6799
# 168026          5999              5999
# 168027          2695               995
# 168028          1450              1377
#
#                                             sizes  \
# 168024                                   S/M,L/XL
# 168025         EURO36,EURO37,EURO38,EURO39,EURO40
# 168026         EURO36,EURO37,EURO38,EURO39,EURO40
# 168027                                    Onesize
# 168028  EURO36,EURO37,EURO38,EURO39,EURO40,EURO41
#
#                                              product_link  \
# 168024  dresses/soch/soch-blue-ethnic-motifs-kaftan-dr...
# 168025  heels/fitflop/fitflop-tan-leather-wedge-sandal...
# 168026  heels/fitflop/fitflop-blue-leather-wedge-pumps...
# 168027  trimmer/vgr/vgr-men-v-015-professional-hair-tr...
# 168028  flats/daisie/daisie-women-grey-printed-open-to...
#
#                                                  img_link product_tag  \
# 168024  https://assets.myntassets.com/dpr_2,q_60,w_210...     dresses
# 168025  https://assets.myntassets.com/dpr_2,q_60,w_210...       heels
# 168026  https://assets.myntassets.com/dpr_2,q_60,w_210...       heels
# 168027  https://assets.myntassets.com/dpr_2,q_60,w_210...     trimmer
# 168028  https://assets.myntassets.com/dpr_2,q_60,w_210...       flats
#
#        brand_tag  discount_amount  discount_percent
# 168024      soch                0                 0
# 168025   fitflop                0                 0
# 168026   fitflop                0                 0
# 168027       vgr             1700                63
# 168028    daisie               73                 5

# %%
# to check how many Rows and columns having in this dataset
data.shape
# Out:
# (168029, 13)

# %%
# want to check the statatics view of the dataset
data.describe()
# Out:
#               rating   rating_count  marked_price  discounted_price  \
# count  168029.000000  168029.000000  168029.00000     168029.000000
# mean        2.264556     114.668658    2509.07457       1515.168757
# std         2.101402     800.207065    2402.10918       1800.460291
# min         0.000000       0.000000      50.00000         49.000000
# 25%         0.000000       0.000000    1295.00000        674.000000
# 50%         3.500000       5.000000    1998.00000        999.000000
# 75%         4.300000      31.000000    2999.00000       1739.000000
# max         5.000000   55900.000000  113999.00000      45900.000000
#
#        discount_amount  discount_percent
# count    168029.000000     168029.000000
# mean        993.905814         37.251909
# std        1236.606569         24.638975
# min           0.000000          0.000000
# 25%         202.000000         15.000000
# 50%         702.000000         40.000000
# 75%        1319.000000         59.000000
# max       68400.000000         91.000000

# %%
# To download and check the complate profile of this data in very short time
# !pip install pandas pandas_profiling
# Out:
# Requirement already satisfied: pandas in c:\users\ashok kumar\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: pandas_profiling in c:\users\ashok kumar\anaconda3\lib\site-packages (3.6.6)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\ashok kumar\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ashok kumar\anaconda3\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ashok kumar\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: ydata-profiling in c:\users\ashok kumar\anaconda3\lib\site-packages (from pandas_profiling) (4.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\ashok kumar\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (0.7.5)
# Requirement already satisfied: typeguard<3,>=2.13.2 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (2.13.3)
# Requirement already satisfied: wordcloud>=1.9.1 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (1.9.2)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (4.64.1)
# Requirement already satisfied: matplotlib<4,>=3.2 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (3.5.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (2.11.3)
# Requirement already satisfied: dacite>=1.8 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (1.8.1)
# Requirement already satisfied: pydantic<2,>=1.8.1 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (1.10.8)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (0.12.3)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (1.9.1)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (0.13.2)
# Requirement already satisfied: scipy<1.11,>=1.4.1 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (1.9.1)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (0.11.2)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (4.3.1)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (0.1.12)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\ashok kumar\anaconda3\lib\site-packages (from ydata-profiling->pandas_profiling) (2.28.1)
# Requirement already satisfied: PyWavelets in c:\users\ashok kumar\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas_profiling) (1.3.0)
# Requirement already satisfied: pillow in c:\users\ashok kumar\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas_profiling) (9.2.0)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\ashok kumar\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (0.2.0)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\ashok kumar\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (21.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\ashok kumar\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (2.8.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ashok kumar\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas_profiling) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ashok kumar\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ashok kumar\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ashok kumar\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ashok kumar\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ashok kumar\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (21.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\ashok kumar\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas_profiling) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\ashok kumar\anaconda3\lib\site-packages (from pydantic<2,>=1.8.1->ydata-profiling->pandas_profiling) (4.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ashok kumar\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ashok kumar\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ashok kumar\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ashok kumar\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (2022.9.14)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\ashok kumar\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas_profiling) (0.5.2)
# Requirement already satisfied: colorama in c:\users\ashok kumar\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling->pandas_profiling) (0.4.5)

# %%
import pandas as pd
import pandas_profiling
# Out:
# C:\Users\Ashok Kumar\AppData\Local\Temp\ipykernel_7528\3826459295.py:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %%
df = pd.read_csv('data.csv')

# %%
profile = df.profile_report(title='Data Profile')

# %%
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
data.head()
# Out:
#                      product_name      brand_name  rating  rating_count  \
# 0   Croc Textured Two Fold Wallet     Lino Perros     0.0             0
# 1             Men Striped Sliders  Mast & Harbour     4.0            76
# 2            Printed A-line Kurta            Biba     4.3            66
# 3    Girls Floral Printed T-shirt        Anthrilo     0.0             0
# 4  Women Printed Kurta with Skirt    FASHION DWAR     0.0             0
#
#    marked_price  discounted_price                      sizes  \
# 0          1295               828                    Onesize
# 1          1299               584  UK6,UK7,UK8,UK9,UK10,UK11
# 2          1999              1599           S,M,L,XL,XXL,3XL
# 3           599               539            7-8Y,8-9Y,9-10Y
# 4          2899              2899                   S,M,L,XL
#
#                                         product_link  \
# 0  wallets/lino-perros/lino-perros-women-peach-co...
# 1  flip-flops/mast--harbour/mast--harbour-men-nav...
# 2  kurtas/biba/biba-women-off-white--black-printe...
# 3  tshirts/anthrilo/anthrilo-girls-white-floral-p...
# 4  kurta-sets/fashion-dwar/fashion-dwar-women-mul...
#
#                                             img_link product_tag  \
# 0  https://assets.myntassets.com/dpr_2,q_60,w_210...     wallets
# 1  https://assets.myntassets.com/dpr_2,q_60,w_210...  flip-flops
# 2  https://assets.myntassets.com/dpr_2,q_60,w_210...      kurtas
# 3  https://assets.myntassets.com/dpr_2,q_60,w_210...     tshirts
# 4  https://assets.myntassets.com/dpr_2,q_60,w_210...  kurta-sets
#
#        brand_tag  discount_amount  discount_percent
# 0    lino-perros              467                36
# 1  mast--harbour              715                55
# 2           biba              400                20
# 3       anthrilo               60                10
# 4   fashion-dwar                0                 0

# %%
profile.to_file('data_profile.html')
# Out:
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
